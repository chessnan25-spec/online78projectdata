# %%
import pandas as pd

# %%
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
conn = create_engine("mysql+pymysql://root:root@localhost:3306/online78")

# %%
conn
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/online78)

# %%
df = pd.read_sql_query("select * from emp where city='pune'",conn)

# %%
df
# Out:
#     id  name  city
# 0  103  Amit  pune

# %%
df = pd.read_sql_table("emp",conn)

# %%
df
# Out:
#         id             name            city
# 0      101           keshav        new pune
# 1      102            Rahul          Mumbai
# 2      103             Amit         Chennai
# 3      103             Amit            pune
# 4        1     Martin Silva     Lake Robert
# ...    ...              ...             ...
# 998    996  Kimberly Maddox  Elizabethburgh
# 999    997   Tammy Anderson      Bobbyville
# 1000   998  Courtney Powell     Kristinside
# 1001   999   Adam Gutierrez        Kevinton
# 1002  1000      Tina Miller  Websterborough
#
# [1003 rows x 3 columns]

# %%
#read -- Data From DB using Pandas

# %%
df = pd.read_html("COVID-19 pandemic by country and territory - Wikipedia.html")

# %%
df = df[12]

# %%
df
# Out:
#                                             Unnamed: 0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239  ^ Countries which do not report data for a col...
#
#                                                Country  \
# 0                                             World[a]
# 1                                                 Peru
# 2                                             Bulgaria
# 3                                      North Macedonia
# ...

# %%
df.to_sql(name="coviddata",
          con=conn,
         if_exists="append")
# Out:
# 240

# %%
table --> append
replace 

fail

# %%
df = pd.read_csv("employee_records.csv")

# %%
df.to_sql(name="emprecords1",
          con=conn,
          if_exists="replace",
          index=False
         )
# Out:
# 100

# %%
SQLALchemy :
Pandas to Database:
=====================

# %%
df.shape
# Out:
# (100, 4)

# %%
2. DataFrame Attributes
df.shape – Get the number of rows and columns (shape).
df.columns – Get the column labels.
df.index – Get the index of the DataFrame.
df.dtypes – Get the data types of columns.
df.size – Get the total number of elements in the DataFrame.
df.ndim – Get the number of dimensions.
df.memory_usage() – Get the memory usage of the DataFrame.
df.describe() – Get summary statistics of the DataFrame.
df.info() – Get concise summary of the DataFrame.

# %%
df.shape
# Out:
# (100, 4)

# %%
df.dtypes
# Out:
# eid          int64
# ename       object
# eemailid    object
# city        object
# dtype: object

# %%
pandas -- object -- str

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   eid       100 non-null    int64
#  1   ename     100 non-null    object
#  2   eemailid  100 non-null    object
#  3   city      100 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB

# %%
df.describe()
# Out:
#               eid
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
EDA --> 

Distrubution

# %%
df
# Out:
#     eid               ename                       eemailid               city
# 0     1        Tamara House            carol99@example.com          Whitestad
# 1     2    Patricia Stevens          hbradford@example.net      East Veronica
# 2     3         Victor Ryan           joseph88@example.com     Gutierrezmouth
# 3     4         David Glass     timothyroberts@example.org   East Kristenstad
# 4     5      Lori Contreras            msawyer@example.com     North Luisside
# ..  ...                 ...                            ...                ...
# 95   96          Jill Tapia              fchen@example.org       South Vernon
# 96   97        Alexis Smith       timothysmith@example.net        Millerburgh
# 97   98         Terry Cohen  gabriellemartinez@example.com         Meghanside
# 98   99  Christopher Berger          heather86@example.org  West Lorrainefurt
# 99  100        Wendy Turner   clarkchristopher@example.net       West Jeffrey
#
# [100 rows x 4 columns]

# %%
df.size
# Out:
# 400

# %%
df.ndim
# Out:
# 2

# %%
df.memory_usage()
# Out:
# Index       132
# eid         800
# ename       800
# eemailid    800
# city        800
# dtype: int64

# %%
#How to select single col

# %%
df
# Out:
#     eid               ename                       eemailid               city
# 0     1        Tamara House            carol99@example.com          Whitestad
# 1     2    Patricia Stevens          hbradford@example.net      East Veronica
# 2     3         Victor Ryan           joseph88@example.com     Gutierrezmouth
# 3     4         David Glass     timothyroberts@example.org   East Kristenstad
# 4     5      Lori Contreras            msawyer@example.com     North Luisside
# ..  ...                 ...                            ...                ...
# 95   96          Jill Tapia              fchen@example.org       South Vernon
# 96   97        Alexis Smith       timothysmith@example.net        Millerburgh
# 97   98         Terry Cohen  gabriellemartinez@example.com         Meghanside
# 98   99  Christopher Berger          heather86@example.org  West Lorrainefurt
# 99  100        Wendy Turner   clarkchristopher@example.net       West Jeffrey
#
# [100 rows x 4 columns]

# %%
df['ename']
# Out:
# 0           Tamara House
# 1       Patricia Stevens
# 2            Victor Ryan
# 3            David Glass
# 4         Lori Contreras
#              ...
# 95            Jill Tapia
# 96          Alexis Smith
# 97           Terry Cohen
# 98    Christopher Berger
# 99          Wendy Turner
# Name: ename, Length: 100, dtype: object

# %%
df['cityasfsdaf']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cityasfsdaf'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df['cityasfsdaf']
#
# ...

# %%
df.get("city1","no col present")
# Out:
# 'no col present'

# %%
df['city']
# Out:
# 0             Whitestad
# 1         East Veronica
# 2        Gutierrezmouth
# 3      East Kristenstad
# 4        North Luisside
#             ...
# 95         South Vernon
# 96          Millerburgh
# 97           Meghanside
# 98    West Lorrainefurt
# 99         West Jeffrey
# Name: city, Length: 100, dtype: object

# %%
df[[col,col1,col2]]

# %%
df[['eid','city']]
# Out:
#     eid               city
# 0     1          Whitestad
# 1     2      East Veronica
# 2     3     Gutierrezmouth
# 3     4   East Kristenstad
# 4     5     North Luisside
# ..  ...                ...
# 95   96       South Vernon
# 96   97        Millerburgh
# 97   98         Meghanside
# 98   99  West Lorrainefurt
# 99  100       West Jeffrey
#
# [100 rows x 2 columns]

# %%
250 cols --> 


Brokers 

Clients

users

b_name,b_id,b_city

c_name,c_city,c_address

# %%
df = pd.read_csv("creditcard.csv")

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df[[col for col in df.columns if col.startswith("V")]]
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V19       V20  \
# ...

# %%
df
# Out:
#     eid               ename                       eemailid               city
# 0     1        Tamara House            carol99@example.com          Whitestad
# 1     2    Patricia Stevens          hbradford@example.net      East Veronica
# 2     3         Victor Ryan           joseph88@example.com     Gutierrezmouth
# 3     4         David Glass     timothyroberts@example.org   East Kristenstad
# 4     5      Lori Contreras            msawyer@example.com     North Luisside
# ..  ...                 ...                            ...                ...
# 95   96          Jill Tapia              fchen@example.org       South Vernon
# 96   97        Alexis Smith       timothysmith@example.net        Millerburgh
# 97   98         Terry Cohen  gabriellemartinez@example.com         Meghanside
# 98   99  Christopher Berger          heather86@example.org  West Lorrainefurt
# 99  100        Wendy Turner   clarkchristopher@example.net       West Jeffrey
#
# [100 rows x 4 columns]

# %%
3. Data Selection
df.loc[] – Label-based indexing for rows and columns.
df.iloc[] – Integer-location based indexing for rows and columns.
df.at[] – Access a single value for a given row/column pair (label-based).
df.iat[] – Access a single value for a given row/column pair (integer-based).
df.query() – Query DataFrame with an expression.
df.filter() – Filter DataFrame with column names or regular expressions.
df.head() – Get the first n rows.
df.tail() – Get the last n rows.
df.sample() – Get random samples from the DataFrame.
df.get() – Retrieve a column by name.
df.select_dtypes() – Select columns based on their data type.

# %%
df = pd.read_csv("emprecords.csv")

# %%
df
# Out:
#     id    name       sal
# 0  101  keshav     54353
# 1  102  madhav    434342
# 2  103  rakesh  23432432
# 3  104    amit    432432

# %%
df.loc[] – Label-based indexing for rows and columns.
df.iloc[] – Integer-location based indexing for rows and columns.

# %%
df
# Out:
#     id    name       sal
# 0  101  keshav     54353
# 1  102  madhav    434342
# 2  103  rakesh  23432432
# 3  104    amit    432432

# %%
loc -- > label based data selection

# %%
df.loc[row,col]
df.loc[start_row : end_row,start_col:end_col]

# %%
df.loc[1:2,"id":"sal"]
# Out:
#     id    name       sal
# 1  102  madhav    434342
# 2  103  rakesh  23432432

# %%
df.loc[0:1,["id","sal"]]
# Out:
#     id     sal
# 0  101   54353
# 1  102  434342

# %%
df
# Out:
#     id    name       sal
# 0  101  keshav     54353
# 1  102  madhav    434342
# 2  103  rakesh  23432432
# 3  104    amit    432432

# %%
df.loc[2,"name"] = "Rakesh"

# %%
df.loc[[0,3],["id","sal"]]
# Out:
#     id     sal
# 0  101   54353
# 3  104  432432

# %%
df
# Out:
#     id    name       sal
# 0  101  keshav     54353
# 1  102  madhav    434342
# 2  103  Rakesh  23432432
# 3  104    amit    432432

# %%
iloc : integer based location

# %%
df.iloc[1:3,0:3]
# Out:
#     id    name       sal
# 1  102  madhav    434342
# 2  103  Rakesh  23432432

# %%
loc  : label based
      start : end  -end inclusive

iloc: integer based
    start:end  --> end value exclusive

# %%
df.iloc[[0,3],0:3]
# Out:
#     id    name     sal
# 0  101  keshav   54353
# 3  104    amit  432432

# %%
at -- label based single value
iat -- integer based single value

# %%
df
# Out:
#     id    name       sal
# 0  101  keshav     54353
# 1  102  madhav    434342
# 2  103  Rakesh  23432432
# 3  104    amit    432432

# %%
df.at[3,"name"] ="test"

# %%
df.iat[3,1]
# Out:
# 'amit'

# %%
df
# Out:
#     id    name       sal
# 0  101  keshav     54353
# 1  102  madhav    434342
# 2  103  Rakesh  23432432
# 3  104    test    432432

# %%
df.query("sal>60000")
# Out:
#     id    name       sal
# 1  102  madhav    434342
# 2  103  Rakesh  23432432
# 3  104    test    432432

# %%
df.query("city=='Whitestad'")
# Out:
#    eid         ename             eemailid       city
# 0    1  Tamara House  carol99@example.com  Whitestad

# %%
df[df['city']=='Whitestad']
# Out:
#    eid         ename             eemailid       city
# 0    1  Tamara House  carol99@example.com  Whitestad

# %%
df
# Out:
#     eid               ename                       eemailid               city
# 0     1        Tamara House            carol99@example.com          Whitestad
# 1     2    Patricia Stevens          hbradford@example.net      East Veronica
# 2     3         Victor Ryan           joseph88@example.com     Gutierrezmouth
# 3     4         David Glass     timothyroberts@example.org   East Kristenstad
# 4     5      Lori Contreras            msawyer@example.com     North Luisside
# ..  ...                 ...                            ...                ...
# 95   96          Jill Tapia              fchen@example.org       South Vernon
# 96   97        Alexis Smith       timothysmith@example.net        Millerburgh
# 97   98         Terry Cohen  gabriellemartinez@example.com         Meghanside
# 98   99  Christopher Berger          heather86@example.org  West Lorrainefurt
# 99  100        Wendy Turner   clarkchristopher@example.net       West Jeffrey
#
# [100 rows x 4 columns]

# %%
df[df['city']=='Gutierrezmouth']
# Out:
#     eid        ename                eemailid            city
# 2     3  Victor Ryan    joseph88@example.com  Gutierrezmouth
# 29   30  Greg Romero  smithsarah@example.com  Gutierrezmouth

# %%
df[df['city'].isin(["Gutierrezmouth","Whitestad"])]
# Out:
#     eid         ename                eemailid            city
# 0     1  Tamara House     carol99@example.com       Whitestad
# 2     3   Victor Ryan    joseph88@example.com  Gutierrezmouth
# 29   30   Greg Romero  smithsarah@example.com  Gutierrezmouth

# %%
df.query("sal>60000 & name=='rakesh'")
# Out:
#     id    name       sal
# 2  103  rakesh  23432432

# %%
df
# Out:
#     id    name       sal
# 0  101  keshav     54353
# 1  102  madhav    434342
# 2  103  rakesh  23432432
# 3  104    amit    432432

# %%
df[df['eemailid'].str.endswith("example.com")]
# Out:
#     eid              ename                       eemailid               city
# 0     1       Tamara House            carol99@example.com          Whitestad
# 2     3        Victor Ryan           joseph88@example.com     Gutierrezmouth
# 4     5     Lori Contreras            msawyer@example.com     North Luisside
# 5     6       John Escobar     jennifersutton@example.com         Port Laura
# 7     8     Julie Schaefer             gallen@example.com       Estradaburgh
# 9    10      Teresa Burton            kylecox@example.com  North Andreahaven
# 11   12    Jennifer Flores         kristina16@example.com          West Cory
# 18   19     Susan Mitchell        reidrebecca@example.com          Kevinfurt
# 20   21    Philip Chandler          calvarado@example.com       Port Melissa
# 23   24    Ronald Espinoza             gjones@example.com         Davisshire
# 29   30        Greg Romero         smithsarah@example.com     Gutierrezmouth
# ...

# %%
df.head() – Get the first n rows.
df.tail() – Get the last n rows.
df.sample() – Get random samples from the DataFrame.
df.get() – Retrieve a column by name.
df.select_dtypes() – Select columns based on their data type.

# %%
df.head(10)
# Out:
#    eid             ename                    eemailid               city
# 0    1      Tamara House         carol99@example.com          Whitestad
# 1    2  Patricia Stevens       hbradford@example.net      East Veronica
# 2    3       Victor Ryan        joseph88@example.com     Gutierrezmouth
# 3    4       David Glass  timothyroberts@example.org   East Kristenstad
# 4    5    Lori Contreras         msawyer@example.com     North Luisside
# 5    6      John Escobar  jennifersutton@example.com         Port Laura
# 6    7    Donna Phillips       iwilliams@example.org       Perkinsville
# 7    8    Julie Schaefer          gallen@example.com       Estradaburgh
# 8    9       Angela Kane     davidwilson@example.net        Robertmouth
# 9   10     Teresa Burton         kylecox@example.com  North Andreahaven

# %%
df.tail()
# Out:
#     eid               ename                       eemailid               city
# 95   96          Jill Tapia              fchen@example.org       South Vernon
# 96   97        Alexis Smith       timothysmith@example.net        Millerburgh
# 97   98         Terry Cohen  gabriellemartinez@example.com         Meghanside
# 98   99  Christopher Berger          heather86@example.org  West Lorrainefurt
# 99  100        Wendy Turner   clarkchristopher@example.net       West Jeffrey

# %%
df.dtypes
# Out:
# eid          int64
# ename       object
# eemailid    object
# city        object
# dtype: object

# %%
df.select_dtypes("O")
# Out:
#                  ename                       eemailid               city
# 0         Tamara House            carol99@example.com          Whitestad
# 1     Patricia Stevens          hbradford@example.net      East Veronica
# 2          Victor Ryan           joseph88@example.com     Gutierrezmouth
# 3          David Glass     timothyroberts@example.org   East Kristenstad
# 4       Lori Contreras            msawyer@example.com     North Luisside
# ..                 ...                            ...                ...
# 95          Jill Tapia              fchen@example.org       South Vernon
# 96        Alexis Smith       timothysmith@example.net        Millerburgh
# 97         Terry Cohen  gabriellemartinez@example.com         Meghanside
# 98  Christopher Berger          heather86@example.org  West Lorrainefurt
# 99        Wendy Turner   clarkchristopher@example.net       West Jeffrey
#
# [100 rows x 3 columns]

# %%
df.sample(25)
# Out:
#     eid             ename                  eemailid                 city
# 9    10     Teresa Burton       kylecox@example.com    North Andreahaven
# 92   93    Kirsten Willis       wpeters@example.net          New Melissa
# 27   28    Charles Miller     chenjason@example.org       Port Brianstad
# 26   27     Dalton Norris  charleslewis@example.net       South Brittany
# 47   48   Reginald Harper    hogantonya@example.com        Stephanieland
# 0     1      Tamara House       carol99@example.com            Whitestad
# 18   19    Susan Mitchell   reidrebecca@example.com            Kevinfurt
# 19   20    Ryan Brown DVM       jason18@example.org  New Christopherfort
# 76   77    Russell Miller        rick72@example.net      Lake Tylermouth
# 65   66     Jane Petersen       megan61@example.org           Pamelatown
# 59   60    William Moreno     jwhitaker@example.net      East Ronaldtown
# 14   15          Kyle Lee       ggibson@example.org            Trevorton
# ...

# %%
Testing 
validation

# %%
df.sample(15)
# Out:
#     eid             ename                    eemailid               city
# 78   79     Alex Anderson          nbaker@example.org           Johnland
# 39   40  Olivia Hernandez           cbray@example.com            Rosston
# 83   84      Daniel Hines     sandrahobbs@example.org       Williamsside
# 57   58     Kathy Huffman     millernancy@example.com       Craigborough
# 80   81     David Francis     craiggamble@example.org          Ryanville
# 65   66     Jane Petersen         megan61@example.org         Pamelatown
# 28   29     Ashley Holden   christopher70@example.net         Moorehaven
# 26   27     Dalton Norris    charleslewis@example.net     South Brittany
# 64   65      Marcus Boone        rhonda74@example.net       Johnstonstad
# 32   33   Angela Phillips        marcus01@example.com     Cassandramouth
# 71   72       Robert Diaz    castrocheryl@example.org     East Wendyfurt
# 61   62   Christine Mckay         pflores@example.net        Watsonburgh
# ...

# %%
df
# Out:
#     eid               ename                       eemailid               city
# 0     1        Tamara House            carol99@example.com          Whitestad
# 1     2    Patricia Stevens          hbradford@example.net      East Veronica
# 2     3         Victor Ryan           joseph88@example.com     Gutierrezmouth
# 3     4         David Glass     timothyroberts@example.org   East Kristenstad
# 4     5      Lori Contreras            msawyer@example.com     North Luisside
# ..  ...                 ...                            ...                ...
# 95   96          Jill Tapia              fchen@example.org       South Vernon
# 96   97        Alexis Smith       timothysmith@example.net        Millerburgh
# 97   98         Terry Cohen  gabriellemartinez@example.com         Meghanside
# 98   99  Christopher Berger          heather86@example.org  West Lorrainefurt
# 99  100        Wendy Turner   clarkchristopher@example.net       West Jeffrey
#
# [100 rows x 4 columns]

# %%
df = pd.read_csv("emprecords.csv")

# %%
df['new col'] = 'test'

# %%
df
# Out:
#     id    name       sal new col
# 0  101  keshav     54353    test
# 1  102  madhav    434342    test
# 2  103  rakesh  23432432    test
# 3  104    amit    432432    test

# %%
import datetime

# %%
df['latest_up']  = datetime.datetime.now()

# %%
df
# Out:
#     id    name       sal new col                  latest_up
# 0  101  keshav     54353    test 2025-11-18 20:59:59.384010
# 1  102  madhav    434342    test 2025-11-18 20:59:59.384010
# 2  103  rakesh  23432432    test 2025-11-18 20:59:59.384010
# 3  104    amit    432432    test 2025-11-18 20:59:59.384010

# %%
#How to remove col

# %%
final = df.drop("new col",axis=1)

# %%
final
# Out:
#     id    name       sal                  latest_up
# 0  101  keshav     54353 2025-11-18 20:59:59.384010
# 1  102  madhav    434342 2025-11-18 20:59:59.384010
# 2  103  rakesh  23432432 2025-11-18 20:59:59.384010
# 3  104    amit    432432 2025-11-18 20:59:59.384010

# %%
final
# Out:
#     id    name       sal                  latest_up
# 0  101  keshav     54353 2025-11-18 20:59:59.384010
# 1  102  madhav    434342 2025-11-18 20:59:59.384010
# 2  103  rakesh  23432432 2025-11-18 20:59:59.384010
# 3  104    amit    432432 2025-11-18 20:59:59.384010

# %%
df.drop("new col",axis=1,inplace=True)

# %%
df
# Out:
#     id    name       sal                  latest_up
# 0  101  keshav     54353 2025-11-18 20:59:59.384010
# 1  102  madhav    434342 2025-11-18 20:59:59.384010
# 2  103  rakesh  23432432 2025-11-18 20:59:59.384010
# 3  104    amit    432432 2025-11-18 20:59:59.384010

# %%
axis =1 --> col 
axis =0 --> row

inplace = False --> new variable store result
inplace = True  --> same variable store result

# %%
df.drop([1,3])
# Out:
#     id    name       sal                  latest_up
# 0  101  keshav     54353 2025-11-18 20:59:59.384010
# 2  103  rakesh  23432432 2025-11-18 20:59:59.384010

# %%
df.drop(columns=["id","latest_up"],inplace=True)

# %%
df
# Out:
#      name       sal
# 0  keshav     54353
# 1  madhav    434342
# 2  rakesh  23432432
# 3    amit    432432

# %%
add col single ,muliple concat
drop col -- single col ,multiple col
row single as well as multiple

# %%
9. String Methods
df.str.contains() – Check if a string contains a substring.
df.str.replace() – Replace substrings in a column.
df.str.upper() – Convert strings to uppercase.
df.str.lower() – Convert strings to lowercase.
df.str.strip() – Remove leading and trailing whitespaces.
df.str.split() – Split strings by a delimiter.
df.str.len() – Get the length of each string.
df.str.findall() – Find all occurrences of a pattern.
df.str.extract() – Extract matched groups from strings.
df.str.slice() – Extract slices from a string.

# %%
df = pd.read_csv("employee_records.csv")

# %%
df[df['ename'].str.contains("Ry")]
# Out:
#     eid           ename              eemailid                 city
# 2     3     Victor Ryan  joseph88@example.com       Gutierrezmouth
# 19   20  Ryan Brown DVM   jason18@example.org  New Christopherfort

# %%
df['newemail'] = df['eemailid'].str.replace("@example.com","")

# %%
df
# Out:
#     eid               ename                       eemailid               city  \
# 0     1        Tamara House            carol99@example.com          Whitestad
# 1     2    Patricia Stevens          hbradford@example.net      East Veronica
# 2     3         Victor Ryan           joseph88@example.com     Gutierrezmouth
# 3     4         David Glass     timothyroberts@example.org   East Kristenstad
# 4     5      Lori Contreras            msawyer@example.com     North Luisside
# ..  ...                 ...                            ...                ...
# 95   96          Jill Tapia              fchen@example.org       South Vernon
# 96   97        Alexis Smith       timothysmith@example.net        Millerburgh
# 97   98         Terry Cohen  gabriellemartinez@example.com         Meghanside
# 98   99  Christopher Berger          heather86@example.org  West Lorrainefurt
# 99  100        Wendy Turner   clarkchristopher@example.net       West Jeffrey
#
#                         newemail
# ...

# %%
df['city'] = df['city'].str.upper()

# %%
df
# Out:
#     eid               ename                       eemailid               city  \
# 0     1        Tamara House            carol99@example.com          WHITESTAD
# 1     2    Patricia Stevens          hbradford@example.net      EAST VERONICA
# 2     3         Victor Ryan           joseph88@example.com     GUTIERREZMOUTH
# 3     4         David Glass     timothyroberts@example.org   EAST KRISTENSTAD
# 4     5      Lori Contreras            msawyer@example.com     NORTH LUISSIDE
# ..  ...                 ...                            ...                ...
# 95   96          Jill Tapia              fchen@example.org       SOUTH VERNON
# 96   97        Alexis Smith       timothysmith@example.net        MILLERBURGH
# 97   98         Terry Cohen  gabriellemartinez@example.com         MEGHANSIDE
# 98   99  Christopher Berger          heather86@example.org  WEST LORRAINEFURT
# 99  100        Wendy Turner   clarkchristopher@example.net       WEST JEFFREY
#
#                         newemail
# ...

# %%
df
# Out:
#     eid               ename                       eemailid               city  \
# 0     1        Tamara House            carol99@example.com          WHITESTAD
# 1     2    Patricia Stevens          hbradford@example.net      EAST VERONICA
# 2     3         Victor Ryan           joseph88@example.com     GUTIERREZMOUTH
# 3     4         David Glass     timothyroberts@example.org   EAST KRISTENSTAD
# 4     5      Lori Contreras            msawyer@example.com     NORTH LUISSIDE
# ..  ...                 ...                            ...                ...
# 95   96          Jill Tapia              fchen@example.org       SOUTH VERNON
# 96   97        Alexis Smith       timothysmith@example.net        MILLERBURGH
# 97   98         Terry Cohen  gabriellemartinez@example.com         MEGHANSIDE
# 98   99  Christopher Berger          heather86@example.org  WEST LORRAINEFURT
# 99  100        Wendy Turner   clarkchristopher@example.net       WEST JEFFREY
#
#                         newemail
# ...

# %%
df['test']= df['eemailid'].str.split('@')

# %%
df
# Out:
#     eid               ename                       eemailid               city  \
# 0     1        Tamara House            carol99@example.com          WHITESTAD
# 1     2    Patricia Stevens          hbradford@example.net      EAST VERONICA
# 2     3         Victor Ryan           joseph88@example.com     GUTIERREZMOUTH
# 3     4         David Glass     timothyroberts@example.org   EAST KRISTENSTAD
# 4     5      Lori Contreras            msawyer@example.com     NORTH LUISSIDE
# ..  ...                 ...                            ...                ...
# 95   96          Jill Tapia              fchen@example.org       SOUTH VERNON
# 96   97        Alexis Smith       timothysmith@example.net        MILLERBURGH
# 97   98         Terry Cohen  gabriellemartinez@example.com         MEGHANSIDE
# 98   99  Christopher Berger          heather86@example.org  WEST LORRAINEFURT
# 99  100        Wendy Turner   clarkchristopher@example.net       WEST JEFFREY
#
# ...

# %%
df['city'].str.len()
# Out:
# 0      9
# 1     13
# 2     14
# 3     16
# 4     14
#       ..
# 95    12
# 96    11
# 97    10
# 98    17
# 99    12
# Name: city, Length: 100, dtype: int64
